# %%
# LLM Output -> text ( unstructred )
# But we can get sttuctured output ( well defined output)
# Easy for integation and parsing
# Uses : Data Extraction (from resume --> Name, last extaction and store in the output in DB)
# Uses : To create and API
# Uses : To Build Ai Agents (to use tools(e.g for calculator we need number from promts), all tools needes strcuted output)

# ways to get structed output : 1) LLM that have to capabilities 2) LLM that doesn't have these capabilities

# %%
# With structed output LLMs
# 1) TypeDict -> way to define dict that has key and values should exist, ensure dict follow specfic structure ( No vallidation just sugesstion )
# 2) Pydentic
# 3) Json Schema

# %%
from typing import TypedDict
class Person(TypedDict):
    name : str
    age : int
    
new_person : Person = {'name' : "Shantnu" , 'age' : 32}
new_person
# Out:
# {'name': 'Shantnu', 'age': 32}

# %%
# Using TypeDict
import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict , Annotated , List , Optional
from datetime import datetime

load_dotenv()
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# Create Schema
class Itenary(TypedDict):
    key_themes : Annotated[List[str] , "give me the theme that we are flowwing for this day in details"]
    day : Annotated[int , "a what number of day it is"]
    time : Annotated[datetime , "a time frame gap it is, e.g (8:00:00 - 2:20:20)"]
    description : str
    estimated_amount : Annotated[Optional[float] , "Give me a esctimated amt of money for this in US $"]
    
llm = ChatOpenAI(model="openai/gpt-4o-mini", openai_api_base="https://openrouter.ai/api/v1", api_key=OPENROUTER_API_KEY) ## LLM 
structured_llm = llm.with_structured_output(Itenary)
results = structured_llm.invoke("give me itenary to travel in india for for 7 days day wise")
print(results)
# Out:
# {'itinerary': [{'day': 1, 'time': 'Morning', 'description': 'Arrive in Delhi, check into hotel, and freshen up.', 'key_themes': ['arrival', 'rest'], 'pros': 5}, {'day': 1, 'time': 'Afternoon', 'description': 'Explore Red Fort and Jama Masjid.', 'key_themes': ['historical sites', 'heritage'], 'pros': 8}, {'day': 1, 'time': 'Evening', 'description': 'Visit India Gate and Connaught Place for shopping/dinner.', 'key_themes': ['shopping', 'dining'], 'pros': 7}, {'day': 2, 'time': 'Morning', 'description': 'Drive to Agra, visit the Taj Mahal.', 'key_themes': ['monuments', 'UNESCO World Heritage'], 'pros': 10}, {'day': 2, 'time': 'Afternoon', 'description': 'Visit Agra Fort.', 'key_themes': ['historical sites', 'forts'], 'pros': 8}, {'day': 3, 'time': 'Morning', 'description': 'Travel to Jaipur, check into hotel.', 'key_themes': ['travel', 'rest'], 'pros': 5}, {'day': 3, 'time': 'Afternoon', 'description': 'Visit Amer Fort and enjoy an elephant ride.', 'key_themes': ['adventure', 'historical sites'], 'pros': 9}, {'day': 3, 'time': 'Evening', 'description': 'Explore local markets and try Rajasthani cuisine.', 'key_themes': ['shopping', 'dining'], 'pros': 7}, {'day': 4, 'time': 'Morning', 'description': 'Visit City Palace and Jantar Mantar.', 'key_themes': ['heritage', 'astronomy'], 'pros': 8}, {'day': 4, 'time': 'Afternoon', 'description': 'Drive to Udaipur, check into hotel.', 'key_themes': ['travel', 'rest'], 'pros': 5}, {'day': 5, 'time': 'Morning', 'description': 'Visit City Palace and Lake Pichola.', 'key_themes': ['scenic views', 'heritage'], 'pros': 9}, {'day': 5, 'time': 'Afternoon', 'description': 'Explore Jagdish Temple and local markets.', 'key_themes': ['culture', 'shopping'], 'pros': 7}, {'day': 6, 'time': 'Morning', 'description': 'Travel to Mumbai, check into hotel.', 'key_themes': ['travel', 'urban exploration'], 'pros': 5}, {'day': 6, 'time': 'Afternoon', 'description': 'Visit the Gateway of India and Elephanta Caves.', 'key_themes': ['monuments', 'history'], 'pros': 8}, {'day': 6, 'time': 'Evening', 'description': 'Explore Colaba and Marine Drive.', 'key_themes': ['scenic views', 'urban life'], 'pros': 7}, {'day': 7, 'time': 'Morning', 'description': 'Visit Chhatrapati Shivaji Maharaj Terminus and local museums.', 'key_themes': ['architecture', 'culture'], 'pros': 7}, {'day': 7, 'time': 'Afternoon', 'description': 'Shopping at local markets or visit Juhu Beach.', 'key_themes': ['relaxation', 'shopping'], 'pros': 6}, {'day': 7, 'time': 'Evening', 'description': 'Departure from Mumbai.', 'key_themes': ['departure', 'reflection'], 'pros': 5}]}

# %%
results
# Out:
# {'day': 1,
#  'time': 'Morning',
#  'description': 'Arrive in Delhi, check into hotel, breakfast.'}
